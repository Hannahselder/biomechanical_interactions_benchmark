# %%
from plot_utils import plot_success_rate_remote_control, plot_subtask_completion_times, plot_deviation_count_remote_control, plot_subtask_end_distance
from df_utils import create_df_remote_control
import matplotlib.pyplot as plt
import numpy as np

# %%
rewards = ['distance_inside_target', 'distance_inside_target_joystick', 'only_distance', 'only_bonus']
cmap = plt.get_cmap('plasma') 
values = np.linspace(0, len(rewards), len(rewards)) 
colors = [cmap(v / 5) for v in values]
#colors = {key: cmap(v / 5) for key, v in zip(rewards, values)}

# %%
df = create_df_remote_control(rewards)

# %%
plot_success_rate_remote_control(df, colors)

# %%
plot_subtask_completion_times(df, colors)

# %%
plot_deviation_count_remote_control("deviation_count_remote_control", df, colors)

# %%
plot_subtask_end_distance(df, colors)
