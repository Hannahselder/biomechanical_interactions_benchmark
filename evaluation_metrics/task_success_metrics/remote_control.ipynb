# %%
from plot_utils import plot_success_rate_remote_control, plot_subtask_completion_times, plot_deviation_count_remote_control, plot_subtask_cum_distance
from df_utils import create_df_remote_control

# %%
rewards = ['distance_inside_target', 'distance_inside_target_joystick', 'only_distance', 'only_bonus']
df = create_df_remote_control(rewards)

# %%
plot_success_rate_remote_control(df)

# %%
plot_subtask_completion_times(df)

# %%
plot_deviation_count_remote_control("deviation_count_remote_control", df)

# %%
plot_subtask_cum_distance(df)
