# %%
from utils import create_df_remote_control, plot_submovement_count_remote_control, plot_refinement_time_remote_control, calculate_endpoint_variance_remote_control, plot_endpoint_variance_remote_control
import matplotlib.pyplot as plt
import numpy as np

# %%
rewards = ['distance_inside_target', 'distance_inside_target_joystick', 'only_distance', 'only_bonus']
cmap = plt.get_cmap('plasma') 
values = np.linspace(0, len(rewards), len(rewards)) 
colors = [cmap(v / 5) for v in values]
df, number_of_episodes = create_df_remote_control(rewards, "../../simulators/")

# %%
plot_submovement_count_remote_control(df, colors)

# %%
plot_refinement_time_remote_control(df, colors)

# %%
endpoint_variance_df = calculate_endpoint_variance_remote_control(rewards, "../../simulators/")
# Out:
# 0.17076674532140648
# 0.174276618660556
# 0.17148012279016678
# 0.1769078278102393
# 0.1766336935449385

# %%
plot_endpoint_variance_remote_control("Remote Control Task", "remote_control", endpoint_variance_df,colors)
# Out:
#                             reward  endpoint_variance
# 0           distance_inside_target           0.170038
# 1  distance_inside_target_joystick           0.106306
# 2                    only_distance           0.174013
# 3                       only_bonus           0.000000
