# %%
from utils import create_df, calculate_endpoint_variance
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
effort_models = ["zero_effort", "dc_effort_w1", "jac_effort_w1", "ctc_effort_w1", "armmovementpaper_effort"]
markers = {"no_bonus": "+", "hit_bonus": "o"}
variations = ["horizontal_target_area", "smaller_targets", "reach_envelope", "distractor"]
variant_names = ["Default", "Transverse", "Small", "Reach Limits", "Distractor"]
fontsize = 15
all_variants = ["default"] + variations
cmap = plt.get_cmap('plasma')  # 'coolwarm', 'plasma'
values = np.linspace(0, len(all_variants), len(all_variants)) 
colors = {key: cmap(v / (len(all_variants))) for key, v in zip(all_variants, values)}
plt.rcParams.update({'font.size': fontsize})

# %%
#read data
folder = os.path.abspath(f"../../simulators/")
sparse_df = {}
sparse_df["default"], _ = create_df(["hit_bonus"], ["zero_effort"], ["dist"], folder, run_nr=1, task = "pointing")
for v in variations:
    sparse_df[v], _ = create_df(["hit_bonus"], ["zero_effort"], ["dist"], folder, run_nr=1, task = "pointing", variation=v)

# %%
fig, ax = plt.subplots(figsize=(5, 3.5))

for i in range(len(all_variants)):
    ax.bar(i, sparse_df[all_variants[i]]['submovements_count'], label=variant_names[i], color=colors[all_variants[i]])

plt.title("Pointing Task Variants")
plt.legend(loc="upper left")
plt.yticks(fontsize=fontsize)
plt.xticks([])
plt.xlabel("Task Variant", fontsize=fontsize)
plt.ylabel("Submovement count", fontsize=fontsize)
plt.savefig("Nr_of_submovements/number_of_submovements_pointing_variants", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(5, 4))

for i in range(len(all_variants)):
    ax.bar(i, sparse_df[all_variants[i]]['RTP'].mean()*100, label=all_variants[i], color=colors[all_variants[i]])

plt.title("Pointing Task Variants")
plt.yticks(fontsize=fontsize)
plt.xticks([])
plt.xlabel("Task Variant", fontsize=fontsize)
plt.ylabel("Refinement time proportion (%)", fontsize=fontsize)
plt.savefig("RTP/RTP_pointing_variants", bbox_inches='tight')

# %%
endpoint_variance_df = {}
endpoint_variance_df["default"] = calculate_endpoint_variance(["hit_bonus"], ["zero_effort"], ["dist"], folder, task = "pointing")
for v in variations:
    endpoint_variance_df[v] = calculate_endpoint_variance(["hit_bonus"], ["zero_effort"], ["dist"], folder, task = "pointing", variation=v)

# %%
fig, ax = plt.subplots(figsize=(5, 4))

for i in range(len(all_variants)):
    ax.bar(i, endpoint_variance_df[all_variants[i]]['endpoint_variance'].mean(), label=all_variants[i], color=colors[all_variants[i]])

plt.title("Pointing Task Variants")
plt.yticks(fontsize=fontsize)
plt.xticks([])
plt.xlabel("Task Variant", fontsize=fontsize)
plt.ylabel("Endpoint Variance", fontsize=fontsize)
plt.savefig("endpoint_variance/endpoint_variance_pointing_variants", bbox_inches='tight')
